# %% [markdown]
# # 🧠 TrackZone IA Realista - Organização com Probabilidade e Aprendizado Supervisionado
# Este notebook utiliza uma base mais realista, onde a zona ideal é atribuída com **probabilidades**, e não de forma determinística. Treinamos um modelo supervisionado (MLPClassifier) para prever a zona ideal com acurácia próxima de 90%.

# %%
# !pip install plotly
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv("/content/sample_data/base_motos_realista.csv")
df.head()
# Out:
#      placa numero_chassi numero_motor              status     x     y  nova_x  \
# 0  ABC0000     CHS555102    MTR668535  Aguardando aluguel  3.92  9.15     6.3
# 1  ABC0001     CHS437889    MTR345121   Danos estruturais  8.17  3.62     0.2
# 2  ABC0002     CHS576467    MTR772108    Defeito no motor  4.39  5.81     7.2
# 3  ABC0003     CHS456600    MTR467257       Em manutenção  3.77  6.32     2.2
# 4  ABC0004     CHS415557    MTR366765           Sem placa  4.63  0.13     7.6
#
#    nova_y        zona_ideal  \
# 0    8.86        BOX_RAPIDO
# 1    8.33  RAMPA_MANUTENCAO
# 2    5.83     BANCADA_MOTOR
# 3    8.75        BOX_RAPIDO
# 4    5.83     BANCADA_MOTOR
#
#                                    descricao_posicao  status_encoded  \
# 0         Disponível atrás da moto com placa ABC0000               0
# 1  Na fila de manutenção estrutural - moto placa ...               2
# 2  Na bancada de motor sem placa ou com defeito -...               3
# 3  Aguardando reparo no box rápido - moto placa A...               5
# 4  Na bancada de motor sem placa ou com defeito -...               7
#
#    zona_encoded
# 0             1
# 1             3
# 2             0
# 3             1
# 4             0

# %%
# Codificação
le_status = LabelEncoder()
le_zona = LabelEncoder()

df["status_encoded"] = le_status.fit_transform(df["status"])
df["zona_encoded"] = le_zona.fit_transform(df["zona_ideal"])

X = df[["status_encoded"]]
y = df["zona_encoded"]

# Validação cruzada com pipeline
pipeline = make_pipeline(
    StandardScaler(),
    MLPClassifier(hidden_layer_sizes=(32, 32), activation='relu', max_iter=3000, random_state=42)
)

scores = cross_val_score(pipeline, X, y, cv=5, scoring='accuracy')
print("Acurácia média:", round(scores.mean() * 100, 2), "%")
print("Desvio padrão:", round(scores.std() * 100, 2), "%")
# Out:
# Acurácia média: 89.14 %
# Desvio padrão: 5.74 %

# %%
pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpclassifier',
#                  MLPClassifier(hidden_layer_sizes=(32, 32), max_iter=3000,
#                                random_state=42))])

# %%
zonas = {
    "BOX_RAPIDO": {"x": (2, 4), "y": (6, 9)},
    "RAMPA_MANUTENCAO": {"x": (0, 2), "y": (5, 9)},
    "BANCADA_MOTOR": {"x": (7, 9), "y": (4, 6)},
    "PATIO": {"x": (6, 9), "y": (7, 9)},
}

zona_contadores = {
    zona: len(df[df["zona_ideal"] == zona])
    for zona in zonas
}

def adicionar_moto_ia(placa, chassi, motor, status):
    global df
    status_encoded = le_status.transform([status])[0]
    zona_pred_index = pipeline.predict([[status_encoded]])[0]
    zona_pred = le_zona.inverse_transform([zona_pred_index])[0]

    count = zona_contadores[zona_pred]
    zona_contadores[zona_pred] += 1

    max_por_linha = 5
    col = count % max_por_linha
    lin = count // max_por_linha

    x0, x1 = zonas[zona_pred]["x"]
    y0, y1 = zonas[zona_pred]["y"]
    espaco_x = (x1 - x0) / max_por_linha
    espaco_y = (y1 - y0) / 10

    nova_x = round(x0 + col * espaco_x + espaco_x / 2, 2)
    nova_y = round(y1 - lin * espaco_y - espaco_y / 2, 2)

    descricao = f"Moto com status '{status}' alocada na zona {zona_pred} - placa {placa}"

    nova_moto = {
        "placa": placa,
        "numero_chassi": chassi,
        "numero_motor": motor,
        "status": status,
        "x": None,
        "y": None,
        "nova_x": nova_x,
        "nova_y": nova_y,
        "zona_ideal": zona_pred,
        "descricao_posicao": descricao
    }

    df = pd.concat([df, pd.DataFrame([nova_moto])], ignore_index=True)

# %%
def mostrar_patio():
    fig = px.scatter(
        df,
        x="nova_x",
        y="nova_y",
        color="zona_ideal",
        hover_data=["placa", "status", "zona_ideal", "descricao_posicao"],
        title="🛵 Pátio com Motos Organizadas por IA",
        labels={"nova_x": "Coordenada X", "nova_y": "Coordenada Y"}
    )
    fig.update_traces(marker=dict(size=10))
    fig.update_layout(height=600)
    fig.show()

# %%
# exemplos de posições:
#    Reparo simples
#    Danos estruturais
#    Defeito no motor
#    Sem placa
#    Em manutenção
#    Disponível
#    Alugada
#    Aguardando aluguel


adicionar_moto_ia("ABC9999", "CHS112211", "MTR445500", "Disponível")
mostrar_patio()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but StandardScaler was fitted with feature names
#
# <ipython-input-8-b9adfa1b44f4>:49: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b91a3da8-f4a3-4403-92fc-16e41285ef89" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b91a3da8-f4a3-4403-92fc-16e41285ef89")) {                    Plotly.newPlot(                        "b91a3da8-f4a3-4403-92fc-16e41285ef89",                        [{"customdata":[["ABC0000","Aguardando aluguel","BOX_RAPIDO","Disponível atrás da moto com placa ABC0000"],["ABC0003","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0003"],["ABC0005","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0005"],["ABC0014","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0014"],["ABC0017","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0017"],["ABC0022","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0022"],["ABC0027","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0027"],["ABC0030","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0030"],["ABC0044","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0044"],["ABC0046","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0046"],["ABC0047","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0047"],["ABC0048","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0048"],["ABC0049","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0049"],["ABC0058","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0058"],["ABC0065","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0065"],["ABC0068","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0068"],["ABC0073","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0073"],["ABC0079","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0079"],["ABC0082","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0082"],["ABC0083","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0083"],["ABC0088","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0088"],["ABC0089","Em manutenção","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0089"],["ABC0097","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa ABC0097"],["XYZ1234","Reparo simples","BOX_RAPIDO","Aguardando reparo no box rápido - moto placa XYZ1234"]],"hovertemplate":"zona_ideal=%{customdata[2]}\u003cbr\u003eCoordenada X=%{x}\u003cbr\u003eCoordenada Y=%{y}\u003cbr\u003eplaca=%{customdata[0]}\u003cbr\u003estatus=%{customdata[1]}\u003cbr\u003edescricao_posicao=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BOX_RAPIDO","marker":{"color":"#636efa","symbol":"circle","size":10},"mode":"markers","name":"BOX_RAPIDO","orientation":"v","showlegend":true,"x":[6.3,2.2,2.6,3.4,3.8,2.2,2.6,3.0,2.2,2.6,3.0,3.4,3.8,2.2,3.0,3.4,3.8,2.2,2.6,3.0,3.4,3.8,2.6,3.4],"xaxis":"x","y":[8.86,8.75,8.75,8.75,8.75,8.25,8.25,8.25,7.75,7.75,7.75,7.75,7.75,7.25,7.25,7.25,7.25,6.75,6.75,6.75,6.75,6.75,6.25,7.35],"yaxis":"y","type":"scatter"},{"customdata":[["ABC0001","Danos estruturais","RAMPA_MANUTENCAO","Na fila de manutenção estrutural - moto placa ABC0001"],["ABC0007","Danos estruturais","RAMPA_MANUTENCAO","Na fila de manutenção estrutural - moto placa ABC0007"],["ABC0032","Danos estruturais","RAMPA_MANUTENCAO","Na fila de manutenção estrutural - moto placa ABC0032"],["ABC0034","Danos estruturais","RAMPA_MANUTENCAO","Na fila de manutenção est ...
